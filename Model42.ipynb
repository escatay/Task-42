# %%
import sys 
import numpy as np
import matplotlib.pyplot as plt
import regression
# %matplotlib inline

# %% [markdown]
# Introduction + Explanation here lol

# %%
#data from hw as placeholder
data = np.loadtxt("poly_data.csv", delimiter = ",")
model = regression.regress(data, "else")
